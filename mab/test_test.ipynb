# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import axelrod.WriteToExcel as WriteToExcel

# %%
p = [player() for player in axl.demo_strategies]

t = axl.Tournament(players=p, repetitions=1)

results = t.play()
results.payoff_matrix
# Out:
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 292.19it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 125.63it/s]
# [[3.0, 0.0, 3.0, 3.0, 1.545],
#  [5.0, 1.0, 1.02, 1.02, 3.1],
#  [3.0, 0.995, 3.0, 3.0, 2.325],
#  [3.0, 0.995, 3.0, 3.0, 3.015],
#  [3.97, 0.475, 2.35, 0.515, 2.2125]]

# %%
results.scores
# Out:
# [[1509], [2028], [1864], [2002], [1462]]
