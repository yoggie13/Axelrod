# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
p = [player() for player in axl.axelrod_first_strategies]

p.append(axl.OptunaFuzzy())

dfs = []

with pd.ExcelWriter(f"Axelrod_First.xlsx") as writer:
    print("Kreiran novi fajl")


for i in range(0, 30):
    print(f"Krećem {i+1}. turnir")
    t = axl.Tournament(players=p, repetitions=1)

    results = t.play()

    results.scores

    
    df = pd.DataFrame(
            {
                "Name": [x.name for x in p],
                "#Wins": list(map(lambda x: sum(x), results.wins)),
                "TotalScore": list(map(lambda x: sum(x), results.scores)),
                "CooperationRating" : results.cooperating_rating,
                "GoodPartnerRating" : results.good_partner_rating,
                "EigenJesusRating" : results.eigenjesus_rating,
                "EigenMosesRating" : results.eigenmoses_rating,
            })


    df = df.sort_values("TotalScore", ascending=False)
    df = df.reset_index(drop=True)
    dfs.append(df)
# Out:
# Kreiran novi fajl
# Krećem 1. turnir
# Playing matches: 100%|██████████| 136/136 [00:06<00:00, 19.62it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 130.42it/s]
# Krećem 2. turnir
# Playing matches: 100%|██████████| 136/136 [00:06<00:00, 19.82it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 99.39it/s]
# Krećem 3. turnir
# Playing matches: 100%|██████████| 136/136 [00:15<00:00,  8.76it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 71.85it/s]
# Krećem 4. turnir
# Playing matches: 100%|██████████| 136/136 [00:16<00:00,  8.06it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 71.12it/s]
# Krećem 5. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00, 10.40it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 77.08it/s]
# Krećem 6. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00, 10.34it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 67.92it/s]
# Krećem 7. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00, 10.42it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 63.83it/s]
# Krećem 8. turnir
# Playing matches: 100%|██████████| 136/136 [00:15<00:00,  8.53it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 80.78it/s]
# Krećem 9. turnir
# Playing matches: 100%|██████████| 136/136 [00:12<00:00, 11.04it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 76.00it/s]
# Krećem 10. turnir
# Playing matches: 100%|██████████| 136/136 [00:12<00:00, 11.16it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 72.60it/s]
# Krećem 11. turnir
# Playing matches: 100%|██████████| 136/136 [00:12<00:00, 11.20it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 52.81it/s]
# Krećem 12. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00, 10.15it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 64.64it/s]
# Krećem 13. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00, 10.44it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 64.63it/s]
# Krećem 14. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00, 10.22it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 59.04it/s]
# Krećem 15. turnir
# Playing matches: 100%|██████████| 136/136 [00:13<00:00,  9.97it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 80.97it/s]
# Krećem 16. turnir
# Playing matches: 100%|██████████| 136/136 [00:16<00:00,  8.29it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 63.13it/s]
# Krećem 17. turnir
# Playing matches: 100%|██████████| 136/136 [00:12<00:00, 10.77it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 62.21it/s]
# Krećem 18. turnir
# Playing matches: 100%|██████████| 136/136 [00:12<00:00, 10.49it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 96.18it/s]
# Krećem 19. turnir
# Playing matches: 100%|██████████| 136/136 [00:11<00:00, 12.06it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 98.77it/s]
# Krećem 20. turnir
# Playing matches: 100%|██████████| 136/136 [00:11<00:00, 12.34it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 102.65it/s]
# Krećem 21. turnir
# Playing matches: 100%|██████████| 136/136 [00:11<00:00, 12.04it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 110.07it/s]
# Krećem 22. turnir
# Playing matches: 100%|██████████| 136/136 [00:10<00:00, 12.79it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 55.59it/s]
# Krećem 23. turnir
# Playing matches: 100%|██████████| 136/136 [00:10<00:00, 12.93it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 100.41it/s]
# Krećem 24. turnir
# Playing matches: 100%|██████████| 136/136 [00:09<00:00, 14.26it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 81.65it/s]
# Krećem 25. turnir
# Playing matches: 100%|██████████| 136/136 [00:09<00:00, 13.67it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 94.46it/s]
# Krećem 26. turnir
# Playing matches: 100%|██████████| 136/136 [00:10<00:00, 12.82it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 84.45it/s]
# Krećem 27. turnir
# Playing matches: 100%|██████████| 136/136 [00:09<00:00, 14.30it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 83.25it/s]
# Krećem 28. turnir
# Playing matches: 100%|██████████| 136/136 [00:09<00:00, 13.87it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 90.08it/s]
# Krećem 29. turnir
# Playing matches: 100%|██████████| 136/136 [00:09<00:00, 14.59it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 84.79it/s]
# Krećem 30. turnir
# Playing matches: 100%|██████████| 136/136 [00:09<00:00, 13.88it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 71.58it/s]

# %%
i = 1
for df in dfs:
    with pd.ExcelWriter(f"Axelrod_First.xlsx", mode="a", engine="openpyxl") as writer:
        df.to_excel(writer, sheet_name="Rank_List_"+str(i), startrow=0)
        i = i+1

# %%
from functools import reduce

prepared = [
    df[["Name", "TotalScore"]].rename(
        columns={"TotalScore": f"TotalScore{i+1}"}
    )
    for i, df in enumerate(dfs)
]

# Merge svih DF-ova po Name
result_df = reduce(
    lambda left, right: pd.merge(left, right, on="Name", how="outer"),
    prepared
)

with pd.ExcelWriter(f"Axelrod_First.xlsx", mode="a", engine="openpyxl") as writer:
        result_df.to_excel(writer, sheet_name="Total Score", startrow=0)

# %%
combined = pd.concat(dfs)
        
agg = combined.groupby('Name').agg({
        '#Wins': 'sum',
        'TotalScore': 'sum',
        'CooperationRating': ['mean', 'std'],
        'GoodPartnerRating': ['mean', 'std'],
        'EigenJesusRating': ['mean', 'std'],
        'EigenMosesRating': ['mean', 'std']
}).reset_index()

agg.columns = ['Name', '#Wins', 'TotalScore',
               'AvgCoopRating', 'SD_CoopRating',
               'AvgGP', 'SD_GP',
               'AvgEJ', 'SD_EJ',
               'AvgEM', 'SD_EM']
        
        # Compute %Wins and AvgScore
num_dfs = len(dfs)
total_matches = (len(p)-1) * num_dfs
agg['%Wins'] = agg['#Wins'] / total_matches
agg['AvgScore'] = agg['TotalScore'] / total_matches
        
        # Keep only desired columns
result = agg[['Name', '%Wins', 'AvgScore',
              'AvgCoopRating', 'SD_CoopRating',
              'AvgGP', 'SD_GP',
              'AvgEJ', 'SD_EJ',
              'AvgEM', 'SD_EM']]
result = result.sort_values(by="AvgScore", ascending=False)


with pd.ExcelWriter(f"Axelrod_First.xlsx", mode="a", engine="openpyxl") as writer:
        result.to_excel(writer, sheet_name="FINAL", startrow=0)

# %%
# Kreiramo prazan dict gde će ključevi biti imena, a vrednosti liste rangova
rank_dict = {}

for i, df in enumerate(dfs):
    # Rang po TotalScore u toj iteraciji
    ranks = df.set_index('Name')['TotalScore'].rank(ascending=False, method='min')
    
    for name, rank in ranks.items():
        if name not in rank_dict:
            rank_dict[name] = []
        rank_dict[name].append(rank)

# Pretvaramo u DataFrame
rank_df = pd.DataFrame.from_dict(rank_dict, orient='index')

# Preimenuj kolone u Rank_1, Rank_2, ...
rank_df.columns = [f'Rank_{i+1}' for i in range(len(rank_df.columns))]

# Reset index da Name bude kolona
rank_df = rank_df.reset_index().rename(columns={'index': 'Name'})

# rank_df sada sadrži 30 kolona rangova po iteracijama
with pd.ExcelWriter(f"Axelrod_First_Ranks.xlsx") as writer:
    rank_df.to_excel(writer, startrow=0)
