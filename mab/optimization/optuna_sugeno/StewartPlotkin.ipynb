# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
p = [player() for player in axl.stewart_plotkin_strategies]

p.append(axl.OptunaFuzzySugeno())

dfs = []

with pd.ExcelWriter(f"Stewart_Plotkin.xlsx") as writer:
    print("Kreiran novi fajl")


for i in range(0, 30):
    print(f"Krećem {i+1}. turnir")
    t = axl.Tournament(players=p, repetitions=1)

    results = t.play()

    results.scores

    
    df = pd.DataFrame(
            {
                "Name": [x.name for x in p],
                "#Wins": list(map(lambda x: sum(x), results.wins)),
                "TotalScore": list(map(lambda x: sum(x), results.scores)),
                "CooperationRating" : results.cooperating_rating,
                "GoodPartnerRating" : results.good_partner_rating,
                "EigenJesusRating" : results.eigenjesus_rating,
                "EigenMosesRating" : results.eigenmoses_rating,
            })


    df = df.sort_values("TotalScore", ascending=False)
    df = df.reset_index(drop=True)
    dfs.append(df)
# Out:
# Kreiran novi fajl
# Krećem 1. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 21.36it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 119.87it/s]
# Krećem 2. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 23.49it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 114.21it/s]
# Krećem 3. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 21.13it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 152.45it/s]
# Krećem 4. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 26.37it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 153.93it/s]
# Krećem 5. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 26.56it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 169.63it/s]
# Krećem 6. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.39it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 193.28it/s]
# Krećem 7. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 29.54it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 159.17it/s]
# Krećem 8. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 25.04it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 160.29it/s]
# Krećem 9. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.44it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 169.92it/s]
# Krećem 10. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 25.10it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 161.79it/s]
# Krećem 11. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.68it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 138.36it/s]
# Krećem 12. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 21.19it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 167.91it/s]
# Krećem 13. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.65it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 158.81it/s]
# Krećem 14. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 25.05it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 142.84it/s]
# Krećem 15. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.19it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 151.42it/s]
# Krećem 16. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 22.86it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 138.25it/s]
# Krećem 17. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 21.95it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 125.23it/s]
# Krećem 18. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.32it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 129.47it/s]
# Krećem 19. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 21.69it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 115.68it/s]
# Krećem 20. turnir
# Playing matches: 100%|██████████| 120/120 [00:07<00:00, 16.36it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 123.35it/s]
# Krećem 21. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 20.78it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 171.83it/s]
# Krećem 22. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 24.64it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 172.91it/s]
# Krećem 23. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 26.45it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 181.76it/s]
# Krećem 24. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 26.89it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 162.11it/s]
# Krećem 25. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 25.34it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 158.32it/s]
# Krećem 26. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 29.68it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 161.45it/s]
# Krećem 27. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 25.93it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 150.49it/s]
# Krećem 28. turnir
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 25.82it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 147.61it/s]
# Krećem 29. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 23.80it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 128.07it/s]
# Krećem 30. turnir
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 23.51it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 120.29it/s]

# %%
i = 1
for df in dfs:
    with pd.ExcelWriter(f"Stewart_Plotkin.xlsx", mode="a", engine="openpyxl") as writer:
        df.to_excel(writer, sheet_name="Rank_List_"+str(i), startrow=0)
        i = i+1

# %%
from functools import reduce

prepared = [
    df[["Name", "TotalScore"]].rename(
        columns={"TotalScore": f"TotalScore{i+1}"}
    )
    for i, df in enumerate(dfs)
]

# Merge svih DF-ova po Name
result_df = reduce(
    lambda left, right: pd.merge(left, right, on="Name", how="outer"),
    prepared
)

with pd.ExcelWriter(f"Stewart_Plotkin.xlsx", mode="a", engine="openpyxl") as writer:
        result_df.to_excel(writer, sheet_name="Total Score", startrow=0)

# %%
combined = pd.concat(dfs)
        
agg = combined.groupby('Name').agg({
        '#Wins': 'sum',
        'TotalScore': 'sum',
        'CooperationRating': ['mean', 'std'],
        'GoodPartnerRating': ['mean', 'std'],
        'EigenJesusRating': ['mean', 'std'],
        'EigenMosesRating': ['mean', 'std']
}).reset_index()

agg.columns = ['Name', '#Wins', 'TotalScore',
               'AvgCoopRating', 'SD_CoopRating',
               'AvgGP', 'SD_GP',
               'AvgEJ', 'SD_EJ',
               'AvgEM', 'SD_EM']
        
        # Compute %Wins and AvgScore
num_dfs = len(dfs)
total_matches = (len(p)-1) * num_dfs
agg['%Wins'] = agg['#Wins'] / total_matches
agg['AvgScore'] = agg['TotalScore'] / total_matches
        
        # Keep only desired columns
result = agg[['Name', '%Wins', 'AvgScore',
              'AvgCoopRating', 'SD_CoopRating',
              'AvgGP', 'SD_GP',
              'AvgEJ', 'SD_EJ',
              'AvgEM', 'SD_EM']]
result = result.sort_values(by="AvgScore", ascending=False)


with pd.ExcelWriter(f"Stewart_Plotkin.xlsx", mode="a", engine="openpyxl") as writer:
        result.to_excel(writer, sheet_name="FINAL", startrow=0)

# %%
# Kreiramo prazan dict gde će ključevi biti imena, a vrednosti liste rangova
rank_dict = {}

for i, df in enumerate(dfs):
    # Rang po TotalScore u toj iteraciji
    ranks = df.set_index('Name')['TotalScore'].rank(ascending=False, method='min')
    
    for name, rank in ranks.items():
        if name not in rank_dict:
            rank_dict[name] = []
        rank_dict[name].append(rank)

# Pretvaramo u DataFrame
rank_df = pd.DataFrame.from_dict(rank_dict, orient='index')

# Preimenuj kolone u Rank_1, Rank_2, ...
rank_df.columns = [f'Rank_{i+1}' for i in range(len(rank_df.columns))]

# Reset index da Name bude kolona
rank_df = rank_df.reset_index().rename(columns={'index': 'Name'})

# rank_df sada sadrži 30 kolona rangova po iteracijama
with pd.ExcelWriter(f"Stewart_Plotkin_Ranks.xlsx") as writer:
    rank_df.to_excel(writer, startrow=0)
