# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
p = [axl.Fuzzy()] + [axl.Random()]
t = axl.Tournament(players=p)

results = t.play()
# Out:
# Playing matches: 100%|██████████| 3/3 [00:06<00:00,  2.29s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 299.57it/s]

# %%
eco = axl.Ecosystem(results=results, population=[0.01, 0.99])
eco.reproduce(10000)

plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_12016\806356072.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_9112\2969901155.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# First

# %%
p = [player() for player in axl.stewart_plotkin_strategies]

p.append(axl.Fuzzy())

t = axl.Tournament(players=p, repetitions=1)

results = t.play()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:03<00:00, 31.37it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 174.07it/s]

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("Stewart_Plotkin")
p.show()
# Out:
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_9112\2604480895.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# Stewart_Plotkin

# %%
p = [player for player in[
    axl.Fuzzy(),
    axl.EvolvedFSM6(),
    axl.EvolvedLookerUp2_2_2(),
    axl.EvolvedHMM5(),
    axl.EvolvedFSM16(),
    axl.TitForTat(),
    axl.GTFT(),
    axl.ZDGTFT2()
    ]]


t = axl.Tournament(players=p)

results = t.play()
# Out:
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 37.36it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 217.12it/s]

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("Final")
p.show()
# Out:
# Final
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_12848\26518516.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.filtered_strategies({
        "long_run_time": False,
})]


t = axl.Tournament(players=p)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("All strategies")
p.show()
# Out:
# Playing matches: 100%|██████████| 25878/25878 [36:38<00:00, 11.77it/s]
# Analysing: 100%|██████████| 25/25 [00:20<00:00,  1.24it/s]
# All strategies
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_9720\3963981099.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.filtered_strategies({
        "long_run_time": False,
})]


t = axl.Tournament(players=p)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("All strategies")
p.show()
# Out:
# Playing matches:  15%|█▌        | 3995/25878 [09:12<50:26,  7.23it/s]
# Playing matches: 100%|██████████| 25878/25878 [42:40<00:00, 10.11it/s]
# Analysing: 100%|██████████| 25/25 [00:20<00:00,  1.21it/s]
# All strategies
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_18456\1037281739.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 21
#      16 p.show()
#      20 # Sort by final population size
# ---> 21 final_pop = eco.population_distribution[-1]
#      22 top_strategies = sorted(final_pop, key=final_pop.get, reverse=True)[:10]
#      24 # Filter results to only top strategies
#
# AttributeError: 'Ecosystem' object has no attribute 'population_distribution'

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("All strategies")
p.show()
# Out:
# All strategies
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_18456\1400977181.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
import pandas as pd

df = pd.DataFrame({
    "Strategy": [str(player) for player in t.players],
    "Final Population": eco.population_sizes[-1]
})
df = df.sort_values(by="Final Population", ascending=False)

# 5. Save to Excel
df.to_excel("axelrod_final_population.xlsx", index=False)

print("Saved to axelrod_final_population.xlsx")
# Out:
# Saved to axelrod_final_population.xlsx

# %%
dfs = []


for i in range(0, 5):
    p = [axl.Fuzzy() for _ in range(5)] + [axl.Defector() for _ in range(35)] + [axl.Random() for _ in range(10)]

    t = axl.Tournament(players=p)

    results = t.play()

    eco = axl.Ecosystem(results)
    eco.reproduce(100)

    plot = axl.Plot(results)
    p = plot.stackplot(eco)
    print("All strategies")
    p.show()

    df = pd.DataFrame({
        "Strategy": [str(player) for player in t.players],
        "Final Population": eco.population_sizes[-1]
    })
    df = df.sort_values(by="Final Population", ascending=False)

    dfs.append(df)

# 5. Save to Excel
j = 0

writer = pd.ExcelWriter('axelrod_final_population_1710.xlsx', engine='xlsxwriter')

for df in dfs:
    df.to_excel(writer, sheet_name=str(j), index=False)
    j += 1

writer.close()
# Out:
# Playing matches: 100%|██████████| 1275/1275 [13:36<00:00,  1.56it/s]
# Analysing: 100%|██████████| 25/25 [00:01<00:00, 14.84it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_6164\133450432.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Playing matches: 100%|██████████| 1275/1275 [13:46<00:00,  1.54it/s]
# Analysing: 100%|██████████| 25/25 [00:01<00:00, 14.76it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_6164\133450432.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Playing matches: 100%|██████████| 1275/1275 [13:48<00:00,  1.54it/s]
# Analysing: 100%|██████████| 25/25 [00:01<00:00, 14.31it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_6164\133450432.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Playing matches: 100%|██████████| 1275/1275 [13:48<00:00,  1.54it/s]
# Analysing: 100%|██████████| 25/25 [00:01<00:00, 13.74it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_6164\133450432.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Playing matches: 100%|██████████| 1275/1275 [13:44<00:00,  1.55it/s]
# Analysing: 100%|██████████| 25/25 [00:01<00:00, 14.79it/s]
# All strategies
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_6164\133450432.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
