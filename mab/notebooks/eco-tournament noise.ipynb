# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
p = [player() for player in axl.axelrod_first_strategies]

p.append(axl.Fuzzy())

t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()
# Out:
# Playing matches: 100%|██████████| 136/136 [00:19<00:00,  7.16it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 68.15it/s]

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_14192\2969901155.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]

p.append(axl.Fuzzy())

t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:20<00:00,  5.98it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 76.62it/s]

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("Stewart_Plotkin")
p.show()
# Out:
# Stewart_Plotkin
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_14192\2604480895.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.filtered_strategies({
    "stochastic": True,
        "long_run_time": False,
})]

p.append(axl.Fuzzy())

t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()
# Out:
# Playing matches: 100%|██████████| 2775/2775 [02:53<00:00, 15.98it/s]
# Analysing: 100%|██████████| 25/25 [00:04<00:00,  6.19it/s]

# %%
eco = axl.Ecosystem(results)
eco.reproduce(100)

plot = axl.Plot(results)
p = plot.stackplot(eco)
print("Stochastic")
p.show()
# Out:
# Stochastic
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_14192\895582534.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
