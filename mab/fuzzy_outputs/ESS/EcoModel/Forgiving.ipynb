# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
dfs = []


for i in range(0, 50):
    print(f"Krećem {i+1} .iteraciju ")
    p = [axl.Fuzzy()] + [axl.TitFor2Tats()] + [axl.HardTitForTat()] + [axl.WinStayLoseShift()] + [axl.Grudger()] + [axl.TitForTat()] + [axl.GTFT()]

    t = axl.Tournament(players=p, noise=0.1)

    results = t.play()

    eco = axl.Ecosystem(results)
    eco.reproduce(10000)

    plot = axl.Plot(results)
    p = plot.stackplot(eco)
    print("All strategies")
    p.show()

    df = pd.DataFrame({
        "Strategy": [str(player) for player in t.players],
        "Final Population": eco.population_sizes[-1]
    })
    df = df.sort_values(by="Final Population", ascending=False)

    dfs.append(df)

# 5. Save to Excel
j = 0

writer = pd.ExcelWriter('axelrod_final_population_forgiving.xlsx', engine='xlsxwriter')

for df in dfs:
    df.to_excel(writer, sheet_name=str(j), index=False)
    j += 1

writer.close()
# Out:
# Krećem 1 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:26<00:00,  3.08s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 62.96it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 2 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:17<00:00,  2.78s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 153.29it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 3 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:27<00:00,  3.12s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 183.99it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 4 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.70s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 165.76it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 5 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.68s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 103.56it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 6 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:18<00:00,  2.79s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 175.55it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 7 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.68s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 146.53it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 8 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:14<00:00,  2.67s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 172.96it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 9 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:10<00:00,  2.53s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 160.61it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 10 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:16<00:00,  2.72s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 117.10it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 11 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.69s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 164.71it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 12 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:13<00:00,  2.64s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 164.45it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 13 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:16<00:00,  2.72s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 167.02it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 14 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:16<00:00,  2.72s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 183.09it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 15 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:18<00:00,  2.81s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 163.39it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 16 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:35<00:00,  3.40s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 75.59it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 17 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:30<00:00,  3.24s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 82.96it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 18 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.71s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 143.64it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 19 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:16<00:00,  2.72s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 179.74it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 20 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:16<00:00,  2.73s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 172.75it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 21 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:20<00:00,  2.86s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 204.69it/s]
# C:\Users\Ognjen\axl_mab\Axelrod\axelrod\plot.py:263: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   _, ax = plt.subplots()
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 22 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.69s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 113.46it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 23 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:22<00:00,  2.95s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 111.90it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 24 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:19<00:00,  2.83s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 174.17it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 25 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:14<00:00,  2.65s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 171.19it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 26 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:18<00:00,  2.80s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 167.82it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 27 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:19<00:00,  2.83s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 108.51it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 28 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:12<00:00,  2.60s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 170.45it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 29 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:17<00:00,  2.76s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 178.35it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 30 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.71s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 163.74it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 31 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:20<00:00,  2.86s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 178.99it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 32 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:16<00:00,  2.73s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 171.50it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 33 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.71s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 163.53it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 34 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:19<00:00,  2.82s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 164.99it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 35 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:17<00:00,  2.78s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 157.64it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 36 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:13<00:00,  2.63s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 182.05it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 37 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:15<00:00,  2.68s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 155.44it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 38 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:11<00:00,  2.56s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 172.76it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 39 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:58<00:00,  2.08s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 212.69it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 40 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:57<00:00,  2.05s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 207.63it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 41 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:57<00:00,  2.04s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 195.34it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 42 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:59<00:00,  2.11s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 195.62it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 43 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:56<00:00,  2.03s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 210.57it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 44 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:56<00:00,  2.03s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 178.77it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 45 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:58<00:00,  2.10s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 205.02it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 46 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:57<00:00,  2.06s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 219.80it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 47 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:57<00:00,  2.06s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 217.77it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 48 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:57<00:00,  2.06s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 225.69it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 49 .iteraciju
# Playing matches: 100%|██████████| 28/28 [00:57<00:00,  2.05s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 187.85it/s]
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
# All strategies
# Krećem 50 .iteraciju
# Playing matches: 100%|██████████| 28/28 [01:00<00:00,  2.15s/it]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 207.59it/s]
# All strategies
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_22008\1735497679.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
