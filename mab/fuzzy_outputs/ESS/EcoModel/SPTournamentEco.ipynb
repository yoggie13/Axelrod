# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import axelrod as axl

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 29.05it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 109.79it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16364\1926448580.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:03<00:00, 30.15it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 172.80it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16364\1926448580.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:04<00:00, 27.53it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 128.70it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16364\1926448580.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 23.20it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 131.53it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16364\1926448580.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:05<00:00, 22.77it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 139.58it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16364\1729123140.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
