# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import axelrod as axl

# %%
p = [player() for player in axl.axelrod_first_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 136/136 [00:05<00:00, 26.06it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 157.39it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16484\2451213778.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.axelrod_first_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 136/136 [00:05<00:00, 26.15it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 96.05it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16484\2451213778.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.axelrod_first_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 136/136 [00:05<00:00, 24.68it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 174.73it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16484\2451213778.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.axelrod_first_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 136/136 [00:05<00:00, 26.54it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 207.17it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16484\2451213778.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.axelrod_first_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 136/136 [00:05<00:00, 22.97it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 177.86it/s]
# First
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_16484\2338852407.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
