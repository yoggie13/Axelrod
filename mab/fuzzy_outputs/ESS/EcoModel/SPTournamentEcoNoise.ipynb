# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import axelrod as axl

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First - 10% noise")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:12<00:00,  9.88it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 94.39it/s]
# First - 10% noise
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_10268\2597296999.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First - 10% noise")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:14<00:00,  8.30it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 142.40it/s]
# First - 10% noise
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_10268\2597296999.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First - 10% noise")
plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:13<00:00,  9.16it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 134.88it/s]
# First - 10% noise
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_10268\2597296999.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First - 10% noise")

plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:13<00:00,  8.82it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 62.91it/s]
# First - 10% noise
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_10268\1743136806.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
p = [player() for player in axl.stewart_plotkin_strategies]


p.append(axl.Fuzzy())


t = axl.Tournament(players=p, repetitions=1, noise=0.1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(10000)

print("First - 10% noise")

plot = axl.Plot(results)
p = plot.stackplot(eco)
p.show()
# Out:
# Playing matches: 100%|██████████| 120/120 [00:13<00:00,  8.98it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 125.83it/s]
# First - 10% noise
# C:\Users\Ognjen\AppData\Local\Temp\ipykernel_10268\1743136806.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
