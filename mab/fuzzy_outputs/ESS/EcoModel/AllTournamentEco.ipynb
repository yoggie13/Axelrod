# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import axelrod as axl
import pandas as pd

# %%
p = [player() for player in axl.filtered_strategies({         "long_run_time": False, })]


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(20000)


df = pd.DataFrame({
    "Strategy": [str(player) for player in t.players],
    "Final Population": eco.population_sizes[-1]
})
df = df.sort_values(by="Final Population", ascending=False)

df.to_excel("axelrod_final_population1.xlsx", index=False)
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.48it/s]

# %%
p = [player() for player in axl.filtered_strategies({         "long_run_time": False, })]


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(20000)


df = pd.DataFrame({
    "Strategy": [str(player) for player in t.players],
    "Final Population": eco.population_sizes[-1]
})
df = df.sort_values(by="Final Population", ascending=False)

df.to_excel("axelrod_final_population2.xlsx", index=False)
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:13<00:00,  1.90it/s]

# %%
p = [player() for player in axl.filtered_strategies({         "long_run_time": False, })]


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(20000)


df = pd.DataFrame({
    "Strategy": [str(player) for player in t.players],
    "Final Population": eco.population_sizes[-1]
})
df = df.sort_values(by="Final Population", ascending=False)

df.to_excel("axelrod_final_population3.xlsx", index=False)
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:12<00:00,  1.93it/s]

# %%
p = [player() for player in axl.filtered_strategies({         "long_run_time": False, })]


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(20000)


df = pd.DataFrame({
    "Strategy": [str(player) for player in t.players],
    "Final Population": eco.population_sizes[-1]
})
df = df.sort_values(by="Final Population", ascending=False)

df.to_excel("axelrod_final_population4.xlsx", index=False)
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:12<00:00,  1.97it/s]

# %%
p = [player() for player in axl.filtered_strategies({         "long_run_time": False, })]


t = axl.Tournament(players=p, repetitions=1)

results = t.play()

eco = axl.Ecosystem(results)
eco.reproduce(20000)


df = pd.DataFrame({
    "Strategy": [str(player) for player in t.players],
    "Final Population": eco.population_sizes[-1]
})
df = df.sort_values(by="Final Population", ascending=False)

df.to_excel("axelrod_final_population5.xlsx", index=False)
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:24<00:00,  1.00it/s]
