# %%
import axelrod as axl
import pandas as pd

# %%
p = [player() for player in axl.filtered_strategies({
        "long_run_time": False,
})]

dfs = []

with pd.ExcelWriter(f"All.xlsx") as writer:
    print("Kreiran novi fajl")


for i in range(0, 30):
    print(f"Krećem {i+1}. turnir")
    t = axl.Tournament(players=p, repetitions=1)

    results = t.play()

    results.scores

    
    df = pd.DataFrame(
            {
                "Name": [x.name for x in p],
                "#Wins": list(map(lambda x: sum(x), results.wins)),
                "TotalScore": list(map(lambda x: sum(x), results.scores)),
                "CooperationRating" : results.cooperating_rating,
                "GoodPartnerRating" : results.good_partner_rating,
                "EigenJesusRating" : results.eigenjesus_rating,
                "EigenMosesRating" : results.eigenmoses_rating,
            })


    df = df.sort_values("TotalScore", ascending=False)
    df = df.reset_index(drop=True)
    dfs.append(df)
# Out:
# Kreiran novi fajl
# Krećem 1. turnir
# Playing matches: 100%|██████████| 26106/26106 [06:51<00:00, 63.44it/s]
# Analysing: 100%|██████████| 25/25 [00:15<00:00,  1.65it/s]
# Krećem 2. turnir
# Playing matches: 100%|██████████| 26106/26106 [09:25<00:00, 46.16it/s]
# Analysing: 100%|██████████| 25/25 [00:19<00:00,  1.27it/s]
# Krećem 3. turnir
# Playing matches: 100%|██████████| 26106/26106 [10:12<00:00, 42.62it/s]
# Analysing: 100%|██████████| 25/25 [00:19<00:00,  1.31it/s]
# Krećem 4. turnir
# Playing matches: 100%|██████████| 26106/26106 [09:19<00:00, 46.70it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.54it/s]
# Krećem 5. turnir
# Playing matches: 100%|██████████| 26106/26106 [07:52<00:00, 55.25it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.53it/s]
# Krećem 6. turnir
# Playing matches: 100%|██████████| 26106/26106 [07:54<00:00, 55.02it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.53it/s]
# Krećem 7. turnir
# Playing matches: 100%|██████████| 26106/26106 [07:56<00:00, 54.75it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.54it/s]
# Krećem 8. turnir
# Playing matches: 100%|██████████| 26106/26106 [07:55<00:00, 54.96it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.53it/s]
# Krećem 9. turnir
# Playing matches: 100%|██████████| 26106/26106 [07:56<00:00, 54.81it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.49it/s]
# Krećem 10. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:41<00:00, 50.08it/s]
# Analysing: 100%|██████████| 25/25 [00:23<00:00,  1.06it/s]
# Krećem 11. turnir
# Playing matches: 100%|██████████| 26106/26106 [10:56<00:00, 39.74it/s]
# Analysing: 100%|██████████| 25/25 [00:21<00:00,  1.15it/s]
# Krećem 12. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:04<00:00, 53.86it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.45it/s]
# Krećem 13. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:31<00:00, 51.08it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.44it/s]
# Krećem 14. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:06<00:00, 53.63it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.48it/s]
# Krećem 15. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:15<00:00, 52.66it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.48it/s]
# Krećem 16. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:08<00:00, 53.45it/s]
# Analysing: 100%|██████████| 25/25 [00:15<00:00,  1.56it/s]
# Krećem 17. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:07<00:00, 53.50it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.44it/s]
# Krećem 18. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:05<00:00, 53.73it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.43it/s]
# Krećem 19. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:05<00:00, 53.78it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.52it/s]
# Krećem 20. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:12<00:00, 53.06it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.51it/s]
# Krećem 21. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:10<00:00, 53.17it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.41it/s]
# Krećem 22. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:11<00:00, 53.09it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.41it/s]
# Krećem 23. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:07<00:00, 53.54it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.55it/s]
# Krećem 24. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:10<00:00, 53.19it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.50it/s]
# Krećem 25. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:12<00:00, 53.01it/s]
# Analysing: 100%|██████████| 25/25 [00:17<00:00,  1.39it/s]
# Krećem 26. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:07<00:00, 53.53it/s]
# Analysing: 100%|██████████| 25/25 [00:18<00:00,  1.36it/s]
# Krećem 27. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:14<00:00, 52.81it/s]
# Analysing: 100%|██████████| 25/25 [00:19<00:00,  1.31it/s]
# Krećem 28. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:11<00:00, 53.07it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.50it/s]
# Krećem 29. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:12<00:00, 53.03it/s]
# Analysing: 100%|██████████| 25/25 [00:16<00:00,  1.53it/s]
# Krećem 30. turnir
# Playing matches: 100%|██████████| 26106/26106 [08:09<00:00, 53.33it/s]
# Analysing: 100%|██████████| 25/25 [00:18<00:00,  1.36it/s]

# %%
i = 1
for df in dfs:
    with pd.ExcelWriter(f"All.xlsx", mode="a", engine="openpyxl") as writer:
        df.to_excel(writer, sheet_name="Rank_List_"+str(i), startrow=0)
        i = i+1

# %%
from functools import reduce

prepared = [
    df[["Name", "TotalScore"]].rename(
        columns={"TotalScore": f"TotalScore{i+1}"}
    )
    for i, df in enumerate(dfs)
]

# Merge svih DF-ova po Name
result_df = reduce(
    lambda left, right: pd.merge(left, right, on="Name", how="outer"),
    prepared
)

with pd.ExcelWriter(f"All.xlsx", mode="a", engine="openpyxl") as writer:
        result_df.to_excel(writer, sheet_name="Total Score", startrow=0)

# %%
combined = pd.concat(dfs)
        
agg = combined.groupby('Name').agg({
        '#Wins': 'sum',
        'TotalScore': 'sum',
        'CooperationRating': ['mean', 'std'],
        'GoodPartnerRating': ['mean', 'std'],
        'EigenJesusRating': ['mean', 'std'],
        'EigenMosesRating': ['mean', 'std']
}).reset_index()

agg.columns = ['Name', '#Wins', 'TotalScore',
               'AvgCoopRating', 'SD_CoopRating',
               'AvgGP', 'SD_GP',
               'AvgEJ', 'SD_EJ',
               'AvgEM', 'SD_EM']
        
        # Compute %Wins and AvgScore
num_dfs = len(dfs)
total_matches = (len(p)-1) * num_dfs
agg['%Wins'] = agg['#Wins'] / total_matches
agg['AvgScore'] = agg['TotalScore'] / total_matches
        
        # Keep only desired columns
result = agg[['Name', '%Wins', 'AvgScore',
              'AvgCoopRating', 'SD_CoopRating',
              'AvgGP', 'SD_GP',
              'AvgEJ', 'SD_EJ',
              'AvgEM', 'SD_EM']]
result = result.sort_values(by="AvgScore", ascending=False)


with pd.ExcelWriter(f"All.xlsx", mode="a", engine="openpyxl") as writer:
        result.to_excel(writer, sheet_name="FINAL", startrow=0)

# %%
# Kreiramo prazan dict gde će ključevi biti imena, a vrednosti liste rangova
rank_dict = {}

for i, df in enumerate(dfs):
    # Rang po TotalScore u toj iteraciji
    ranks = df.set_index('Name')['TotalScore'].rank(ascending=False, method='min')
    
    for name, rank in ranks.items():
        if name not in rank_dict:
            rank_dict[name] = []
        rank_dict[name].append(rank)

# Pretvaramo u DataFrame
rank_df = pd.DataFrame.from_dict(rank_dict, orient='index')

# Preimenuj kolone u Rank_1, Rank_2, ...
rank_df.columns = [f'Rank_{i+1}' for i in range(len(rank_df.columns))]

# Reset index da Name bude kolona
rank_df = rank_df.reset_index().rename(columns={'index': 'Name'})

# rank_df sada sadrži 30 kolona rangova po iteracijama
with pd.ExcelWriter(f"All_Ranks.xlsx") as writer:
    rank_df.to_excel(writer, startrow=0)
