# %%
import axelrod as axl
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import axelrod.WriteToExcel as WriteToExcel
import importlib

# %%
p = [player() for player in axl.filtered_strategies({
    "long_run_time": False,
})]


for i in range(0, 1):
    print(f"Krećem {i+1}. turnir")
    t = axl.Tournament(players=p, repetitions=1)

    results = t.play()

    results.scores

WriteToExcel.write_to_excel()
# Out:
# Krećem 1. turnir
# Playing matches: 100%|██████████| 26106/26106 [13:56<00:00, 31.20it/s]
# Analysing: 100%|██████████| 25/25 [00:15<00:00,  1.63it/s]
